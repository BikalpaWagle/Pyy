# %%
print("Hello")
# Out:
# Hello

# %%
# !pip install pandas
# !pip install matplot
# !pip install seaborn
# !pip install numpy
# Out:
# Requirement already satisfied: pandas in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplot in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (0.1.9)
# Requirement already satisfied: pyloco>=0.0.134 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from matplot) (0.0.139)
# Requirement already satisfied: matplotlib>=3.1.1 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from matplot) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.1.1->matplot) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.1.1->matplot) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.1.1->matplot) (4.55.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.1.1->matplot) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.1.1->matplot) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\roaming\python\python313\site-packages (from matplotlib>=3.1.1->matplot) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.1.1->matplot) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.1.1->matplot) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.1.1->matplot) (2.9.0.post0)
# Requirement already satisfied: ushlex in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from pyloco>=0.0.134->matplot) (0.99.1)
# Requirement already satisfied: websocket-client in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from pyloco>=0.0.134->matplot) (1.8.0)
# Requirement already satisfied: twine in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from pyloco>=0.0.134->matplot) (6.0.1)
# Requirement already satisfied: typing in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from pyloco>=0.0.134->matplot) (3.7.4.3)
# Requirement already satisfied: SimpleWebSocketServer in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from pyloco>=0.0.134->matplot) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.1->matplot) (1.16.0)
# Requirement already satisfied: pkginfo>=1.8.1 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (1.12.0)
# Requirement already satisfied: readme-renderer>=35.0 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (44.0)
# Requirement already satisfied: requests>=2.20 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (2.32.3)
# Requirement already satisfied: requests-toolbelt!=0.9.0,>=0.8.0 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (1.0.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (2.2.3)
# Requirement already satisfied: keyring>=15.1 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (25.5.0)
# Requirement already satisfied: rfc3986>=1.4.0 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (2.0.0)
# Requirement already satisfied: rich>=12.0.0 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from twine->pyloco>=0.0.134->matplot) (13.9.4)
# Requirement already satisfied: jaraco.classes in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from keyring>=15.1->twine->pyloco>=0.0.134->matplot) (3.4.0)
# Requirement already satisfied: jaraco.functools in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from keyring>=15.1->twine->pyloco>=0.0.134->matplot) (4.1.0)
# Requirement already satisfied: jaraco.context in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from keyring>=15.1->twine->pyloco>=0.0.134->matplot) (6.0.1)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from keyring>=15.1->twine->pyloco>=0.0.134->matplot) (0.2.3)
# Requirement already satisfied: nh3>=0.2.14 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (0.2.20)
# Requirement already satisfied: docutils>=0.21.2 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (0.21.2)
# Requirement already satisfied: Pygments>=2.5.1 in c:\users\dell\appdata\roaming\python\python313\site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (2.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (2024.12.14)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from rich>=12.0.0->twine->pyloco>=0.0.134->matplot) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->twine->pyloco>=0.0.134->matplot) (0.1.2)
# Requirement already satisfied: more-itertools in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from jaraco.classes->keyring>=15.1->twine->pyloco>=0.0.134->matplot) (10.5.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: seaborn in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.1.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (2.1.3)
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd
import seaborn  as sns
import matplotlib.pyplot as plt
years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

# create a line chart, years on x-axis, gdp on y-axis
plt.plot(years, gdp, color='green', marker='+', linestyle='dotted')

# add a title
plt.title("Nominal GDP")

# add a label to the y-axisYears
plt.ylabel("Billions of $")
plt.xlabel("Years")
plt.show()

# %% [markdown]
# ### BAR CHART

# %%
import pandas as pd
import seaborn  as sns
import matplotlib.pyplot as plt

flight = sns.load_dataset('flights') # load flight dataset
print(flight)

flight_new = flight.groupby('year').sum(numeric_only=True).reset_index()
# line chart
sns.lineplot(x='year',y='passengers',data=flight_new)
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]
# <Axes: xlabel='year', ylabel='passengers'>

# %% [markdown]
# ### BAR PLOT

# %%
import pandas as pd
import seaborn  as sns
import matplotlib.pyplot as plt

# %%
movies = ["Annie Hall", "Ben-Hur", "Casablanca", "Gandhi", "West Side Story"]
num_oscars = [5, 11, 3, 8, 10]

# plot bars with left x-coordinates [0, 1, 2, 3, 4], heights [num_oscars]
plt.bar(range(len(movies)), num_oscars)

plt.title("My Favorite Movies")     # add a title
plt.ylabel("# of Academy Awards")   # label the y-axis

# label x-axis with movie names at bar centers
plt.xticks(range(len(movies)), movies)

plt.show()

# %% [markdown]
# ### Import the external file

# %%
# Load dataset

# Load dataset
def load_dataset(file_path):
  return pd.read_csv(file_path)


df = load_dataset("titanic.csv")
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.countplot(data=df, x='Sex')
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# ### PIE CHART

# %%
df['Sex'].value_counts().plot(kind='pie',autopct='%0.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### BOX PLOT

# %%
import pandas as pd
import seaborn  as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd
import seaborn  as sns
import matplotlib.pyplot as plt
tips = sns.load_dataset('tips')
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x='total_bill', y='tip',hue='sex', style='smoker',data=tips)
plt.show()

# %%
sns.heatmap(flight.pivot_table(values='passengers',index='month',columns='year'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sns.heatmap(flight.pivot_table(values='passengers',index='month',columns='year'))
#
# NameError: name 'flight' is not defined
